# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\STUDY\Data Science\IPL Analysis\IPL Matches 2008-2020.csv")
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
df.shape
# Out:
# (816, 17)

# %%
df.describe()
# Out:
#                  id  neutral_venue  result_margin
# count  8.160000e+02     816.000000     799.000000
# mean   7.563496e+05       0.094363      17.321652
# std    3.058943e+05       0.292512      22.068427
# min    3.359820e+05       0.000000       1.000000
# 25%    5.012278e+05       0.000000       6.000000
# 50%    7.292980e+05       0.000000       8.000000
# 75%    1.082626e+06       0.000000      19.500000
# max    1.237181e+06       1.000000     146.000000

# %%
df['player_of_match'].value_counts()
# Out:
# AB de Villiers    23
# CH Gayle          22
# RG Sharma         18
# DA Warner         17
# MS Dhoni          17
#                   ..
# S Anirudha         1
# M Kartik           1
# R McLaren          1
# RJ Harris          1
# PJ Cummins         1
# Name: player_of_match, Length: 233, dtype: int64

# %%
df['player_of_match'].value_counts()[0:10]
# Out:
# AB de Villiers    23
# CH Gayle          22
# RG Sharma         18
# DA Warner         17
# MS Dhoni          17
# SR Watson         16
# YK Pathan         16
# SK Raina          14
# V Kohli           13
# G Gambhir         13
# Name: player_of_match, dtype: int64

# %%
obj2=df['player_of_match'].value_counts()[0:5].keys()
obj2
# Out:
# Index(['AB de Villiers', 'CH Gayle', 'RG Sharma', 'DA Warner', 'MS Dhoni'], dtype='object')

# %%
obj1=df['player_of_match'].value_counts()[0:5]
obj1
# Out:
# AB de Villiers    23
# CH Gayle          22
# RG Sharma         18
# DA Warner         17
# MS Dhoni          17
# Name: player_of_match, dtype: int64

# %%
plt.figure(figsize=(8,5))
plt.bar(df['player_of_match'].value_counts()[0:5].keys(),df['player_of_match'].value_counts()[0:5],color="g")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.barh(df['player_of_match'].value_counts()[0:5].keys(),df['player_of_match'].value_counts()[0:5],color="g")
plt.show()

# %%
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df[['team1','team2','winner','result_margin']].value_counts()[0:5]
# Out:
# team1                  team2                  winner                 result_margin
# Sunrisers Hyderabad    Kings XI Punjab        Sunrisers Hyderabad    5.0              4
#                        Mumbai Indians         Sunrisers Hyderabad    7.0              3
# Kolkata Knight Riders  Rajasthan Royals       Kolkata Knight Riders  8.0              3
# Kings XI Punjab        Chennai Super Kings    Kings XI Punjab        6.0              3
# Sunrisers Hyderabad    Kolkata Knight Riders  Kolkata Knight Riders  7.0              3
# dtype: int64

# %%
df['toss_winner'].value_counts()
# Out:
# Mumbai Indians                 106
# Kolkata Knight Riders           98
# Chennai Super Kings             97
# Royal Challengers Bangalore     87
# Rajasthan Royals                87
# Kings XI Punjab                 85
# Delhi Daredevils                80
# Sunrisers Hyderabad             57
# Deccan Chargers                 43
# Pune Warriors                   20
# Delhi Capitals                  20
# Gujarat Lions                   15
# Kochi Tuskers Kerala             8
# Rising Pune Supergiants          7
# Rising Pune Supergiant           6
# Name: toss_winner, dtype: int64

# %%
df['toss_winner'].value_counts()[0:10]
# Out:
# Mumbai Indians                 106
# Kolkata Knight Riders           98
# Chennai Super Kings             97
# Royal Challengers Bangalore     87
# Rajasthan Royals                87
# Kings XI Punjab                 85
# Delhi Daredevils                80
# Sunrisers Hyderabad             57
# Deccan Chargers                 43
# Pune Warriors                   20
# Name: toss_winner, dtype: int64

# %%
df[['toss_winner','toss_decision']].value_counts()[0:10]
# Out:
# toss_winner                  toss_decision
# Kolkata Knight Riders        field            64
# Royal Challengers Bangalore  field            63
# Kings XI Punjab              field            58
# Mumbai Indians               field            58
# Rajasthan Royals             field            53
# Chennai Super Kings          bat              51
# Delhi Daredevils             field            51
# Mumbai Indians               bat              48
# Chennai Super Kings          field            46
# Rajasthan Royals             bat              34
# dtype: int64

# %%
batting_first=df[df['result_margin']>50]
batting_first
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 9     335991  Chandigarh  2008-04-25   KC Sangakkara
# 41    336023      Jaipur  2008-05-17        GC Smith
# 55    336038      Mumbai  2008-05-30       SR Watson
# 59    392182   Cape Town  2009-04-18        R Dravid
# ..       ...         ...         ...             ...
# 788  1216524       Dubai  2020-10-27         WP Saha
# 794  1216530       Dubai  2020-11-01      PJ Cummins
# 804  1216540     Sharjah  2020-10-12  AB de Villiers
# 806  1216542       Dubai  2020-10-08     JM Bairstow
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 9    Punjab Cricket Association Stadium, Mohali              0
# 41                       Sawai Mansingh Stadium              0
# 55                             Wankhede Stadium              0
# ...

# %%
batting_first=df[df['result_margin']>50]
batting_first
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 9     335991  Chandigarh  2008-04-25   KC Sangakkara
# 41    336023      Jaipur  2008-05-17        GC Smith
# 55    336038      Mumbai  2008-05-30       SR Watson
# 59    392182   Cape Town  2009-04-18        R Dravid
# ..       ...         ...         ...             ...
# 788  1216524       Dubai  2020-10-27         WP Saha
# 794  1216530       Dubai  2020-11-01      PJ Cummins
# 804  1216540     Sharjah  2020-10-12  AB de Villiers
# 806  1216542       Dubai  2020-10-08     JM Bairstow
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 9    Punjab Cricket Association Stadium, Mohali              0
# 41                       Sawai Mansingh Stadium              0
# 55                             Wankhede Stadium              0
# ...

# %%
plt.hist(batting_first['result_margin'])
plt.title("Distribution of Runs")
plt.xlabel("Runs")
plt.show()

# %%
batting_first['winner']
# Out:
# 0            Kolkata Knight Riders
# 9                  Kings XI Punjab
# 41                Rajasthan Royals
# 55                Rajasthan Royals
# 59     Royal Challengers Bangalore
#                   ...
# 788            Sunrisers Hyderabad
# 794          Kolkata Knight Riders
# 804    Royal Challengers Bangalore
# 806            Sunrisers Hyderabad
# 812                 Mumbai Indians
# Name: winner, Length: 62, dtype: object

# %%
batting_first['winner'].value_counts()
# Out:
# Chennai Super Kings            13
# Mumbai Indians                 12
# Royal Challengers Bangalore     8
# Rajasthan Royals                6
# Kolkata Knight Riders           5
# Kings XI Punjab                 5
# Delhi Daredevils                4
# Sunrisers Hyderabad             4
# Deccan Chargers                 3
# Rising Pune Supergiant          1
# Delhi Capitals                  1
# Name: winner, dtype: int64

# %%
plt.figure(figsize=(6,6))
plt.bar(list(batting_first['winner'].value_counts().keys()[0:3]),list(batting_first['winner'].value_counts()[0:3]))
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.pie(list(batting_first['winner'].value_counts()),labels=list(batting_first['winner'].value_counts().keys()))
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.pie(list(batting_first['winner'].value_counts()),labels=list(batting_first['winner'].value_counts().keys()),autopct='%0.1f%%')
plt.show()

# %%
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df['city'].value_counts()
# Out:
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          65
# Hyderabad          64
# Chennai            57
# Chandigarh         56
# Jaipur             47
# Pune               38
# Abu Dhabi          29
# Dubai              26
# Bengaluru          15
# Durban             15
# Visakhapatnam      13
# Ahmedabad          12
# Sharjah            12
# Centurion          12
# Rajkot             10
# Dharamsala          9
# Indore              9
# Johannesburg        8
# Cuttack             7
# Cape Town           7
# Port Elizabeth      7
# Ranchi              7
# Raipur              6
# Kochi               5
# Kanpur              4
# East London         3
# Kimberley           3
# Nagpur              3
# Bloemfontein        2
# Name: city, dtype: int64

# %%
import numpy as np
np.sum(df['toss_winner']==df['winner'])
# Out:
# 418
